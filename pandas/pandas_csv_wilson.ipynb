# %% [markdown]
# Visualizzi tutti i dati presenti nel dataset

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import io   
df = pd.read_csv('country_vaccinations.csv')  
df
# Out:
#           country  ...                                     source_website
# 0     Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 1     Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 2     Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 3     Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 4     Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# ...           ...  ...                                                ...
# 7612     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1373715027...
# 7613     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1373715027...
# 7614     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1373715027...
# 7615     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1373715027...
# 7616     Zimbabwe  ...  https://twitter.com/MoHCCZim/status/1373715027...
#
# [7617 rows x 15 columns]

# %% [markdown]
# Visualizzi i dati relativi all’Italia

# %%
df[df['country'].isin(['Italy'])]
# Out:
#      country  ...                                     source_website
# 3608   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3609   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3610   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3611   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3612   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# ...      ...  ...                                                ...
# 3688   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3689   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3690   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3691   Italy  ...  https://github.com/italia/covid19-opendata-vac...
# 3692   Italy  ...  https://github.com/italia/covid19-opendata-vac...
#
# [85 rows x 15 columns]

# %% [markdown]
# Conti quante registrazioni sono relative all’Italia

# %%
# Out:
# country                                85
# iso_code                               85
# date                                   85
# total_vaccinations                     85
# people_vaccinated                      85
# people_fully_vaccinated                64
# daily_vaccinations_raw                 84
# daily_vaccinations                     84
# total_vaccinations_per_hundred         85
# people_vaccinated_per_hundred          85
# people_fully_vaccinated_per_hundred    64
# daily_vaccinations_per_million         84
# vaccines                               85
# source_name                            85
# source_website                         85
# dtype: int64

# %% [markdown]
# Visualizzi l’elenco delle nazioni in cui non sono ancora state fatte vaccinazioni

# %%
df['total_vaccinations'].sort_values()
# Out:
# 0       0.0
# 3782    0.0
# 3693    0.0
# 1266    0.0
# 3340    0.0
#        ...
# 7520    NaN
# 7521    NaN
# 7586    NaN
# 7587    NaN
# 7588    NaN
# Name: total_vaccinations, Length: 7617, dtype: float64
